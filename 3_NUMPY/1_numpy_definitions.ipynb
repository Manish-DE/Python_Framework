# %%
"""
numpy_definitions.py

Concise definitions of key NumPy concepts.
"""

def get_definitions():
    """
    Return a dictionary of short NumPy definitions.
    """
    return {
        "NumPy": "A Python library for numerical computing providing the ndarray and fast vectorized operations.",
        "ndarray": "N-dimensional array object storing elements of the same dtype in a contiguous buffer.",
        "dtype": "Data type descriptor of array elements (e.g., int32, float64); determines memory layout and operations.",
        "shape": "Tuple of dimension sizes for an array, e.g., (3, 4) for 3 rows and 4 columns.",
        "ndim": "Number of array dimensions (rank).",
        "size": "Total number of elements in the array (product of shape).",
        "itemsize": "Memory size in bytes of each array element.",
        "axis": "Dimension index along which operations are applied (0 for rows, 1 for columns, etc.).",
        "broadcasting": "Rules that allow arithmetic between arrays of different shapes by virtually expanding them without copying data.",
        "ufunc": "Universal function: vectorized elementwise functions implemented in C (e.g., add, sin).",
        "vectorization": "Using array operations/ufuncs to operate on whole arrays without explicit Python loops.",
        "indexing": "Accessing array elements using integers, slices, tuples for multi-axis selection.",
        "slicing": "Selecting subarrays with start:stop:step syntax producing views when possible.",
        "boolean_indexing": "Selecting elements using boolean arrays of the same shape to filter values.",
        "fancy_indexing": "Indexing with integer arrays to select arbitrary subsets; returns copies.",
        "view_vs_copy": "Slicing usually returns a view (shared memory); fancy indexing returns a copy.",
        "memory_layout": "Order of elements in memory: C-order (row-major) or F-order (column-major).",
        "reshape": "Return a new view or copy with a different shape without changing data order when possible.",
        "ravel_vs_flatten": "ravel returns a view when possible; flatten always returns a copy.",
        "concatenate_stack_split": "Functions to join (concatenate, stack) or divide (split) arrays along axes.",
        "aggregate_functions": "Summaries computed along axes (sum, mean, std, min, max, etc.).",
        "lin_alg": "numpy.linalg submodule for linear algebra: dot, matmul, inv, eig, svd.",
        "random": "numpy.random submodule for pseudo-random number generation and distributions.",
        "transpose": "Permute axes of an array (swap rows/columns for 2D).",
        "dot_vs_matmul": "dot does sum-product over last and second-last axes; @ (matmul) follows matrix multiplication rules.",
        "dtype_casting": "Rules for converting between dtypes in operations; may upcast to preserve information.",
    }

if __name__ == "__main__":
    defs = get_definitions()
    for k, v in defs.items():
        print(f"{k}: {v}")
# Out:
# NumPy: A Python library for numerical computing providing the ndarray and fast vectorized operations.
# ndarray: N-dimensional array object storing elements of the same dtype in a contiguous buffer.
# dtype: Data type descriptor of array elements (e.g., int32, float64); determines memory layout and operations.
# shape: Tuple of dimension sizes for an array, e.g., (3, 4) for 3 rows and 4 columns.
# ndim: Number of array dimensions (rank).
# size: Total number of elements in the array (product of shape).
# itemsize: Memory size in bytes of each array element.
# axis: Dimension index along which operations are applied (0 for rows, 1 for columns, etc.).
# broadcasting: Rules that allow arithmetic between arrays of different shapes by virtually expanding them without copying data.
# ufunc: Universal function: vectorized elementwise functions implemented in C (e.g., add, sin).
# vectorization: Using array operations/ufuncs to operate on whole arrays without explicit Python loops.
# ...
